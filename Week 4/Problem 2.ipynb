# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
houseData = pd.read_csv('train.csv')
houseData.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
houseCatData = pd.DataFrame(houseData[['MSSubClass', 'Neighborhood', 'BldgType', 'OverallQual','SalePrice']])
houseCatData.head()
# Out:
#    MSSubClass Neighborhood BldgType  OverallQual  SalePrice
# 0          60      CollgCr     1Fam            7     208500
# 1          20      Veenker     1Fam            6     181500
# 2          60      CollgCr     1Fam            7     223500
# 3          70      Crawfor     1Fam            7     140000
# 4          60      NoRidge     1Fam            8     250000

# %%
houseCatData = houseCatData.astype('category')
houseCatData.dtypes
# Out:
# MSSubClass      category
# Neighborhood    category
# BldgType        category
# OverallQual     category
# SalePrice       category
# dtype: object

# %%
houseCatData.describe()
# Out:
#         MSSubClass Neighborhood BldgType  OverallQual  SalePrice
# count         1460         1460     1460         1460       1460
# unique          15           25        5           10        663
# top             20        NAmes     1Fam            5     140000
# freq           536          225     1220          397         20

# %%
print(houseCatData["MSSubClass"].value_counts())
sb.catplot(y = "MSSubClass", data = houseCatData, kind = "count")
# Out:
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: MSSubClass, dtype: int64

# %%
print(houseCatData["Neighborhood"].value_counts())
sb.catplot(y = "Neighborhood", data = houseCatData, kind = "count")
# Out:
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# SWISU       25
# StoneBr     25
# Blmngtn     17
# MeadowV     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: Neighborhood, dtype: int64

# %%
print(houseCatData["BldgType"].value_counts())
sb.catplot(y = "BldgType", data = houseCatData, kind = "count")
# Out:
# 1Fam      1220
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: BldgType, dtype: int64

# %%
print(houseCatData["OverallQual"].value_counts())
sb.catplot(y = "OverallQual", data = houseCatData, kind = "count")
# Out:
# 5     397
# 6     374
# 7     319
# 8     168
# 4     116
# 9      43
# 3      20
# 10     18
# 2       3
# 1       2
# Name: OverallQual, dtype: int64

# %%
sb.catplot(y = 'OverallQual', data = houseCatData, col = 'MSSubClass', kind = 'count', col_wrap = 2, height = 8)

# %%
sb.catplot(y = 'OverallQual', data = houseCatData, col = 'Neighborhood', kind = 'count', col_wrap = 2, height = 8)

# %%
sb.catplot(y = 'OverallQual', data = houseCatData, col = 'BldgType', kind = 'count', col_wrap = 2, height = 8)

# %%
f, axes = plt.subplots(figsize=(15, 15))
sb.heatmap(houseCatData.groupby(['MSSubClass', 'OverallQual']).size().unstack() , linewidths = 1, annot = True)

# %%
f, axes = plt.subplots(figsize=(15, 15))
sb.heatmap(houseCatData.groupby(['Neighborhood', 'OverallQual']).size().unstack() , linewidths = 1, annot = True)

# %%
f, axes = plt.subplots(figsize=(15, 5))
sb.heatmap(houseCatData.groupby(['BldgType', 'OverallQual']).size().unstack() , linewidths = 1, annot = True)

# %%
sb.boxplot(x = 'MSSubClass'  , y = 'SalePrice' , data = houseCatData)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-b1cba2f17afa> in <module>
# ----> 1 sb.boxplot(x = 'MSSubClass'  , y = 'SalePrice' , data = houseCatData)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2231             whis=1.5, ax=None, **kwargs):
#    2232
# -> 2233     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2234                           orient, color, palette, saturation,
#    2235                           width, dodge, fliersize, linewidth)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     434                  width, dodge, fliersize, linewidth):
# ...

# %%
sb.boxplot(x = 'Neighborhood'  , y = 'SalePrice' , data = houseCatData)

# %%
sb.boxplot(x = 'BldgType'  , y = 'SalePrice' , data = houseCatData)

# %%
sb.boxplot(x = 'OverallQual'  , y = 'SalePrice' , data = houseCatData)
